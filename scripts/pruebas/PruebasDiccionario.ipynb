# %%
import numpy as np
import pandas as pd

# %%
diccionario = np.load("Materiales\C01_V01.npy", allow_pickle=True).item()

# %%
diccionario
# Out:
# {'feature_list': [{'key': 'sweep',
#    'name': 'Range segment',
#    'sensors': [1],
#    'options': {'Start': 0.1,
#     'Stop': 0.24,
#     'Down sample': 8.0,
#     'Flip': False,
#     'Stretch': False,
#     'Calibrate': False},
#    'output': {'segment': True, 'integrated': False},
#    'model_dimension': 2}],
#  'sweep_data': {'sensor_config_dump': '{"mode": "IQ", "sensor": [1], "range_interval": [0.1, 0.24], "profile": "PROFILE_1", "update_rate": 30.0, "sampling_mode": "A", "repetition_mode": "HOST_DRIVEN", "downsampling_factor": 1, "hw_accelerated_average_samples": 10, "gain": 0.5, "maximize_signal_attenuation": false, "noise_level_normalization": true, "depth_lowpass_cutoff_ratio": null, "tx_disable": false, "power_save_mode": "ACTIVE", "asynchronous_measurement": true}',
#   'module_key': 'iq',
#   'processing_config_dump': '{"history_length": 100, "sf": null, "VERSION": 2}',
#   'rss_version': '2.7.1',
#   'lib_version': '3.10.1',
#   'timestamp': '2021-05-26T23:14:47',
# ...

# %%
diccionario.get('frame_data').get('sweep_data'),diccionario.get('sweep_data').get('data')
# Out:
# (array([[ -32. -10.j,  -33. -11.j,  -34. -12.j,  -34. -12.j,  -34. -13.j,
#           -34. -14.j,  -33. -14.j,  -32. -14.j,  -31. -15.j,  -30. -15.j,
#           -29. -16.j,  -27. -16.j,  -25. -17.j,  -23. -18.j,  -21. -18.j,
#           -19. -19.j,  -17. -20.j,  -15. -20.j,  -13. -20.j,  -12. -20.j,
#           -11. -20.j,  -10. -20.j,   -9. -20.j,   -9. -20.j,   -9. -20.j,
#            -9. -20.j,  -10. -20.j,  -12. -19.j,  -14. -19.j,  -17. -19.j,
#           -20. -19.j,  -24. -19.j,  -29. -19.j,  -35. -19.j,  -42. -19.j,
#           -50. -19.j,  -58. -19.j,  -67. -19.j,  -77. -19.j,  -87. -19.j,
#           -98. -19.j, -109. -18.j, -121. -17.j, -133. -16.j, -145. -14.j,
#          -157. -12.j, -169.  -9.j, -181.  -6.j, -193.  -3.j, -204.  +1.j,
#          -214.  +5.j, -224.  +9.j, -233. +14.j, -241. +19.j, -248. +25.j,
#          -253. +31.j, -258. +37.j, -262. +44.j, -264. +51.j, -265. +58.j,
#          -265. +66.j, -264. +74.j, -262. +82.j, -259. +90.j, -255. +98.j,
# ...

# %%
train = np.load ('train.npy')
test = np.load ('test.npy')

# %%
train = train[0] #train1
test = test [0] #test1

# %%
traindf = pd.DataFrame(train)
testdf = pd.DataFrame(test)

# %%
'''
traindf.to_csv (r'train1.csv', index = False, header=True)
testdf.to_csv (r'test1.csv', index = False, header=True)
'''

# %%
'''
traindf.to_excel(r'train1.xlsx', index = False)
traindf.to_excel(r'train1.xlsx', index = False)
'''

# %%
traindf.columns = np.array(["data"]*int(traindf.shape[1]/2) +  ["fase"]*int(traindf.shape[1]/2) )
list(traindf.columns)
# Out:
# ['data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
#  'data',
# ...

# %%
traindf
# Out:
#           data       data       data       data       data       data  \
# 0    16.941006  18.125100  19.278947  20.452260  21.599654  22.717725
# 1    24.244936  25.915495  27.510506  29.037248  30.481935  31.807403
# 2    14.100210  15.005607  15.850642  16.653614  17.428738  18.149540
# 3    15.543215  16.573975  17.555347  18.505998  19.386224  20.222897
# 4    16.832342  17.955744  19.001120  20.000207  20.956732  21.866171
# ..         ...        ...        ...        ...        ...        ...
# 265  18.397111  19.465922  20.436264  21.354218  22.175116  22.924463
# 266  15.515588  16.539096  17.487205  18.364905  19.168512  19.913207
# 267  15.639727  16.591398  17.496365  18.321593  19.097249  19.795716
# 268  12.391175  13.050385  13.597332  14.081188  14.525416  14.911955
# 269  12.015601  12.667788  13.299791  13.851982  14.395274  14.883536
#
#           data       data       data       data  ...      fase      fase  \
# ...

# %%
y_train = np.array(["carton"]*int(train.shape[0]/3) +  ["plastico"]*int(train.shape[0]/3) +  ["cristal"]*int(train.shape[0]/3))
y_test = np.array(["carton"]*int(test.shape[0]/3) +  ["plastico"]*int(test.shape[0]/3) +  ["cristal"]*int(test.shape[0]/3))

# %%
y_train
# Out:
# array(['carton', 'carton', 'carton', 'carton', 'carton', 'carton',
#        'carton', 'carton', 'carton', 'carton', 'carton', 'carton',
#        'carton', 'carton', 'carton', 'carton', 'carton', 'carton',
#        'carton', 'carton', 'carton', 'carton', 'carton', 'carton',
#        'carton', 'carton', 'carton', 'carton', 'carton', 'carton',
#        'carton', 'carton', 'carton', 'carton', 'carton', 'carton',
#        'carton', 'carton', 'carton', 'carton', 'carton', 'carton',
#        'carton', 'carton', 'carton', 'carton', 'carton', 'carton',
#        'carton', 'carton', 'carton', 'carton', 'carton', 'carton',
#        'carton', 'carton', 'carton', 'carton', 'carton', 'carton',
#        'carton', 'carton', 'carton', 'carton', 'carton', 'carton',
#        'carton', 'carton', 'carton', 'carton', 'carton', 'carton',
#        'carton', 'carton', 'carton', 'carton', 'carton', 'carton',
#        'carton', 'carton', 'carton', 'carton', 'carton', 'carton',
# ...
