# %%
#K-Nearest Neighbors

# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import itertools 

#Ignorar warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#Se define la la función que muestra la matriz de confusión
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks([-0.5,0,1,2,2.5], ["","carton","plastico","cristal"])

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalizar matriz de confusion")
    #else:
        #print('Matriz de confusion')

    #print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
train = np.load ('train.npy')
test = np.load ('test.npy')

# %%
print(len(train),len(train[0]),len(train[0][0]))
# Out:
# 10 270 582

# %%
k_range = range(1,27)
medias_neig = []
#Entrenamos el modelo dejando fuera una vista por objeto en cada interacción con las particiones ya creadas
for k in k_range:
    x_train = list()
    y_train = list()
    x_test = list()
    y_test = list()
    y_prds = list()
    y_prds2 = list()
    y_test2 = list()
    media = 0
    
    modelo = KNeighborsClassifier(n_neighbors=k) #MEJOR = 1
    print("NEIGHBORS " + str(k))
    
    for i in range(len(train)):
        x_train = list()
        x_test = list()
        y_train = list()
        y_test = list()
        print("Particion ", i + 1)

        y_train = np.array(["carton"]*int(train[i].shape[0]/3) 
                        +  ["plastico"]*int(train[i].shape[0]/3) 
                        +  ["cristal"]*int(train[i].shape[0]/3))
        y_test = np.array(["carton"]*int(test[i].shape[0]/3) 
                       +  ["plastico"]*int(test[i].shape[0]/3) 
                       +  ["cristal"]*int(test[i].shape[0]/3))
        #print(len(y_train[0]))
        x_train = train[i]
        x_test = test[i]

        #for j in range(len(train[i])):
        #    x_train.append(train[i][j])

        modelo.fit(x_train,y_train)

        y_prds = modelo.predict(x_test)
        score = metrics.accuracy_score(y_test, y_prds)

        y_test2.extend(y_test)
        y_prds2.extend(y_prds)
        
        
        print('Tasa de acierto:',score)
        media += score
        '''
        #Confusion matrix
        #cm = confusion_matrix(y_test, y_prds)
        plt.figure() #num=None, figsize=(8, 6), dpi=80
        plot_confusion_matrix(confusion_matrix(y_test, y_prds), classes= ["carton","plastico","cristal"], 
                              title='Matriz de Confusion ' + str(i+1))
        plt.show()
        '''

    print("TODAS LAS PARTICIONES")
    print("Tasa de acierto promedio: {0: 0.4f}".format(media/len(test)))

    medias_neig.append(media/len(test))

    #Confusion matrix (TODO)
    #cm = confusion_matrix(y_test2, y_prds2)
    plt.figure() #num=None, figsize=(8, 6), dpi=80
    plot_confusion_matrix(confusion_matrix(y_test2, y_prds2), classes= ["carton","plastico","cristal"], 
                          title='Matriz de Confusion')
    plt.show()
# Out:
# NEIGHBORS 1
# Particion  1
# Tasa de acierto: 0.8
# Particion  2
# Tasa de acierto: 0.8
# Particion  3
# Tasa de acierto: 0.9333333333333333
# Particion  4
# Tasa de acierto: 0.9
# Particion  5
# Tasa de acierto: 0.9
# Particion  6
# Tasa de acierto: 0.8
# Particion  7
# Tasa de acierto: 0.9
# Particion  8
# Tasa de acierto: 1.0
# Particion  9
# Tasa de acierto: 0.8333333333333334
# Particion  10
# Tasa de acierto: 0.9
# TODAS LAS PARTICIONES
# Tasa de acierto promedio:  0.8767
# NEIGHBORS 2
# Particion  1
# Tasa de acierto: 0.6333333333333333
# Particion  2
# Tasa de acierto: 0.7333333333333333
# Particion  3
# Tasa de acierto: 0.9
# Particion  4
# Tasa de acierto: 0.9
# Particion  5
# Tasa de acierto: 0.8
# Particion  6
# Tasa de acierto: 0.7333333333333333
# Particion  7
# Tasa de acierto: 0.8666666666666667
# Particion  8
# Tasa de acierto: 0.9666666666666667
# Particion  9
# Tasa de acierto: 0.8
# Particion  10
# Tasa de acierto: 0.8666666666666667
# TODAS LAS PARTICIONES
# Tasa de acierto promedio:  0.8200
# NEIGHBORS 3
# Particion  1
# Tasa de acierto: 0.8333333333333334
# Particion  2
# Tasa de acierto: 0.8
# Particion  3
# Tasa de acierto: 0.9333333333333333
# Particion  4
# Tasa de acierto: 0.9333333333333333
# Particion  5
# Tasa de acierto: 0.9
# Particion  6
# Tasa de acierto: 0.8
# Particion  7
# Tasa de acierto: 0.8333333333333334
# Particion  8
# Tasa de acierto: 0.8666666666666667
# Particion  9
# Tasa de acierto: 0.8
# Particion  10
# Tasa de acierto: 0.8
# TODAS LAS PARTICIONES
# Tasa de acierto promedio:  0.8500
# NEIGHBORS 4
# Particion  1
# Tasa de acierto: 0.7666666666666667
# Particion  2
# Tasa de acierto: 0.7
# Particion  3
# Tasa de acierto: 0.9
# Particion  4
# Tasa de acierto: 0.9333333333333333
# Particion  5
# Tasa de acierto: 0.8666666666666667
# Particion  6
# Tasa de acierto: 0.8
# Particion  7
# Tasa de acierto: 0.8
# Particion  8
# Tasa de acierto: 0.8333333333333334
# Particion  9
# Tasa de acierto: 0.8333333333333334
# Particion  10
# Tasa de acierto: 0.8666666666666667
# TODAS LAS PARTICIONES
# Tasa de acierto promedio:  0.8300
# NEIGHBORS 5
# Particion  1
# Tasa de acierto: 0.8
# Particion  2
# Tasa de acierto: 0.8
# Particion  3
# Tasa de acierto: 0.9333333333333333
# Particion  4
# Tasa de acierto: 0.9333333333333333
# Particion  5
# Tasa de acierto: 0.8666666666666667
# Particion  6
# Tasa de acierto: 0.8666666666666667
# Particion  7
# Tasa de acierto: 0.8666666666666667
# Particion  8
# Tasa de acierto: 0.8666666666666667
# Particion  9
# Tasa de acierto: 0.8
# Particion  10
# Tasa de acierto: 0.8666666666666667
# TODAS LAS PARTICIONES
# Tasa de acierto promedio:  0.8600
# NEIGHBORS 6
# Particion  1
# Tasa de acierto: 0.7666666666666667
# Particion  2
# Tasa de acierto: 0.7666666666666667
# Particion  3
# Tasa de acierto: 0.8
# Particion  4
# Tasa de acierto: 0.9333333333333333
# Particion  5
# Tasa de acierto: 0.8666666666666667
# Particion  6
# Tasa de acierto: 0.8666666666666667
# Particion  7
# Tasa de acierto: 0.8666666666666667
# Particion  8
# Tasa de acierto: 0.8666666666666667
# Particion  9
# Tasa de acierto: 0.8333333333333334
# Particion  10
# Tasa de acierto: 0.8333333333333334
# TODAS LAS PARTICIONES
# Tasa de acierto promedio:  0.8400
# NEIGHBORS 7
# Particion  1
# Tasa de acierto: 0.8333333333333334
# Particion  2
# Tasa de acierto: 0.7666666666666667
# Particion  3
# Tasa de acierto: 0.9333333333333333
# Particion  4
# Tasa de acierto: 0.9333333333333333
# Particion  5
# Tasa de acierto: 0.8666666666666667
# Particion  6
# Tasa de acierto: 0.8333333333333334
# Particion  7
# Tasa de acierto: 0.8666666666666667
# Particion  8
# Tasa de acierto: 0.8666666666666667
# Particion  9
# Tasa de acierto: 0.8333333333333334
# Particion  10
# Tasa de acierto: 0.8333333333333334
# TODAS LAS PARTICIONES
# Tasa de acierto promedio:  0.8567
# NEIGHBORS 8
# Particion  1
# Tasa de acierto: 0.8
# Particion  2
# Tasa de acierto: 0.8
# Particion  3
# Tasa de acierto: 0.9
# Particion  4
# Tasa de acierto: 0.9333333333333333
# Particion  5
# Tasa de acierto: 0.9
# Particion  6
# Tasa de acierto: 0.8333333333333334
# Particion  7
# Tasa de acierto: 0.8333333333333334
# Particion  8
# Tasa de acierto: 0.9
# Particion  9
# Tasa de acierto: 0.8333333333333334
# Particion  10
# Tasa de acierto: 0.8
# TODAS LAS PARTICIONES
# Tasa de acierto promedio:  0.8533
# NEIGHBORS 9
# Particion  1
# Tasa de acierto: 0.8
# Particion  2
# Tasa de acierto: 0.8
# Particion  3
# Tasa de acierto: 0.9333333333333333
# Particion  4
# Tasa de acierto: 0.9333333333333333
# Particion  5
# Tasa de acierto: 0.9
# Particion  6
# Tasa de acierto: 0.8333333333333334
# Particion  7
# Tasa de acierto: 0.8666666666666667
# Particion  8
# Tasa de acierto: 0.9
# Particion  9
# Tasa de acierto: 0.8333333333333334
# Particion  10
# Tasa de acierto: 0.8333333333333334
# TODAS LAS PARTICIONES
# Tasa de acierto promedio:  0.8633
# NEIGHBORS 10
# Particion  1
# Tasa de acierto: 0.8
# Particion  2
# Tasa de acierto: 0.7333333333333333
# Particion  3
# Tasa de acierto: 0.9
# Particion  4
# Tasa de acierto: 0.9333333333333333
# Particion  5
# Tasa de acierto: 0.9
# Particion  6
# Tasa de acierto: 0.8666666666666667
# Particion  7
# Tasa de acierto: 0.8666666666666667
# Particion  8
# Tasa de acierto: 0.8666666666666667
# Particion  9
# Tasa de acierto: 0.8333333333333334
# Particion  10
# Tasa de acierto: 0.8
# TODAS LAS PARTICIONES
# Tasa de acierto promedio:  0.8500
# NEIGHBORS 11
# Particion  1
# Tasa de acierto: 0.8
# Particion  2
# Tasa de acierto: 0.7333333333333333
# Particion  3
# Tasa de acierto: 0.8666666666666667
# Particion  4
# Tasa de acierto: 0.8666666666666667
# Particion  5
# Tasa de acierto: 0.9
# Particion  6
# Tasa de acierto: 0.8666666666666667
# Particion  7
# Tasa de acierto: 0.8666666666666667
# Particion  8
# Tasa de acierto: 0.8666666666666667
# Particion  9
# Tasa de acierto: 0.8333333333333334
# Particion  10
# Tasa de acierto: 0.7666666666666667
# TODAS LAS PARTICIONES
# Tasa de acierto promedio:  0.8367
# NEIGHBORS 12
# Particion  1
# Tasa de acierto: 0.8333333333333334
# Particion  2
# Tasa de acierto: 0.7
# Particion  3
# Tasa de acierto: 0.8666666666666667
# Particion  4
# Tasa de acierto: 0.9
# Particion  5
# Tasa de acierto: 0.9
# Particion  6
# Tasa de acierto: 0.8333333333333334
# Particion  7
# Tasa de acierto: 0.8666666666666667
# Particion  8
# Tasa de acierto: 0.9
# Particion  9
# Tasa de acierto: 0.8333333333333334
# Particion  10
# Tasa de acierto: 0.8
# TODAS LAS PARTICIONES
# Tasa de acierto promedio:  0.8433
# NEIGHBORS 13
# Particion  1
# Tasa de acierto: 0.8
# Particion  2
# Tasa de acierto: 0.7666666666666667
# Particion  3
# Tasa de acierto: 0.8666666666666667
# Particion  4
# Tasa de acierto: 0.8666666666666667
# Particion  5
# Tasa de acierto: 0.9
# Particion  6
# Tasa de acierto: 0.8333333333333334
# Particion  7
# Tasa de acierto: 0.8333333333333334
# Particion  8
# Tasa de acierto: 0.8333333333333334
# Particion  9
# Tasa de acierto: 0.8333333333333334
# Particion  10
# Tasa de acierto: 0.7666666666666667
# TODAS LAS PARTICIONES
# Tasa de acierto promedio:  0.8300
# NEIGHBORS 14
# Particion  1
# Tasa de acierto: 0.8333333333333334
# Particion  2
# Tasa de acierto: 0.7333333333333333
# Particion  3
# Tasa de acierto: 0.9
# Particion  4
# Tasa de acierto: 0.8666666666666667
# Particion  5
# Tasa de acierto: 0.8333333333333334
# Particion  6
# Tasa de acierto: 0.8333333333333334
# Particion  7
# Tasa de acierto: 0.8
# Particion  8
# Tasa de acierto: 0.8333333333333334
# Particion  9
# Tasa de acierto: 0.8
# Particion  10
# Tasa de acierto: 0.7333333333333333
# TODAS LAS PARTICIONES
# Tasa de acierto promedio:  0.8167
# NEIGHBORS 15
# Particion  1
# Tasa de acierto: 0.8
# Particion  2
# Tasa de acierto: 0.7
# Particion  3
# Tasa de acierto: 0.8333333333333334
# Particion  4
# Tasa de acierto: 0.8666666666666667
# Particion  5
# Tasa de acierto: 0.8333333333333334
# Particion  6
# Tasa de acierto: 0.8333333333333334
# Particion  7
# Tasa de acierto: 0.8
# Particion  8
# Tasa de acierto: 0.8333333333333334
# Particion  9
# Tasa de acierto: 0.8
# Particion  10
# Tasa de acierto: 0.7333333333333333
# TODAS LAS PARTICIONES
# Tasa de acierto promedio:  0.8033
# NEIGHBORS 16
# Particion  1
# Tasa de acierto: 0.8
# Particion  2
# Tasa de acierto: 0.6666666666666666
# Particion  3
# Tasa de acierto: 0.8666666666666667
# Particion  4
# Tasa de acierto: 0.8666666666666667
# Particion  5
# Tasa de acierto: 0.8333333333333334
# Particion  6
# Tasa de acierto: 0.8333333333333334
# Particion  7
# Tasa de acierto: 0.8333333333333334
# Particion  8
# Tasa de acierto: 0.9
# Particion  9
# Tasa de acierto: 0.8
# Particion  10
# Tasa de acierto: 0.8333333333333334
# TODAS LAS PARTICIONES
# Tasa de acierto promedio:  0.8233
# NEIGHBORS 17
# Particion  1
# Tasa de acierto: 0.8
# Particion  2
# Tasa de acierto: 0.7
# Particion  3
# Tasa de acierto: 0.8333333333333334
# Particion  4
# Tasa de acierto: 0.8666666666666667
# Particion  5
# Tasa de acierto: 0.8666666666666667
# Particion  6
# Tasa de acierto: 0.8333333333333334
# Particion  7
# Tasa de acierto: 0.8
# Particion  8
# Tasa de acierto: 0.8666666666666667
# Particion  9
# Tasa de acierto: 0.7666666666666667
# Particion  10
# Tasa de acierto: 0.7666666666666667
# TODAS LAS PARTICIONES
# Tasa de acierto promedio:  0.8100
# NEIGHBORS 18
# Particion  1
# Tasa de acierto: 0.8
# Particion  2
# Tasa de acierto: 0.6666666666666666
# Particion  3
# Tasa de acierto: 0.8333333333333334
# Particion  4
# Tasa de acierto: 0.8666666666666667
# Particion  5
# Tasa de acierto: 0.8666666666666667
# Particion  6
# Tasa de acierto: 0.8
# Particion  7
# Tasa de acierto: 0.8
# Particion  8
# Tasa de acierto: 0.9
# Particion  9
# Tasa de acierto: 0.7666666666666667
# Particion  10
# Tasa de acierto: 0.8333333333333334
# TODAS LAS PARTICIONES
# Tasa de acierto promedio:  0.8133
# NEIGHBORS 19
# Particion  1
# Tasa de acierto: 0.8
# Particion  2
# Tasa de acierto: 0.6666666666666666
# Particion  3
# Tasa de acierto: 0.8333333333333334
# Particion  4
# Tasa de acierto: 0.8666666666666667
# Particion  5
# Tasa de acierto: 0.8333333333333334
# Particion  6
# Tasa de acierto: 0.8333333333333334
# Particion  7
# Tasa de acierto: 0.8
# Particion  8
# Tasa de acierto: 0.9
# Particion  9
# Tasa de acierto: 0.7666666666666667
# Particion  10
# Tasa de acierto: 0.8
# TODAS LAS PARTICIONES
# Tasa de acierto promedio:  0.8100
# NEIGHBORS 20
# Particion  1
# Tasa de acierto: 0.8
# Particion  2
# Tasa de acierto: 0.6666666666666666
# Particion  3
# Tasa de acierto: 0.8333333333333334
# Particion  4
# Tasa de acierto: 0.8333333333333334
# Particion  5
# Tasa de acierto: 0.8333333333333334
# Particion  6
# Tasa de acierto: 0.8333333333333334
# Particion  7
# Tasa de acierto: 0.8
# Particion  8
# Tasa de acierto: 0.9
# Particion  9
# Tasa de acierto: 0.7666666666666667
# Particion  10
# Tasa de acierto: 0.8
# TODAS LAS PARTICIONES
# Tasa de acierto promedio:  0.8067
# NEIGHBORS 21
# Particion  1
# Tasa de acierto: 0.8
# Particion  2
# Tasa de acierto: 0.6333333333333333
# Particion  3
# Tasa de acierto: 0.8
# Particion  4
# Tasa de acierto: 0.8333333333333334
# Particion  5
# Tasa de acierto: 0.8333333333333334
# Particion  6
# Tasa de acierto: 0.8333333333333334
# Particion  7
# Tasa de acierto: 0.7666666666666667
# Particion  8
# Tasa de acierto: 0.9
# Particion  9
# Tasa de acierto: 0.7666666666666667
# Particion  10
# Tasa de acierto: 0.7666666666666667
# TODAS LAS PARTICIONES
# Tasa de acierto promedio:  0.7933
# NEIGHBORS 22
# Particion  1
# Tasa de acierto: 0.7666666666666667
# Particion  2
# Tasa de acierto: 0.6666666666666666
# Particion  3
# Tasa de acierto: 0.8
# Particion  4
# Tasa de acierto: 0.8333333333333334
# Particion  5
# Tasa de acierto: 0.8
# Particion  6
# Tasa de acierto: 0.8666666666666667
# Particion  7
# Tasa de acierto: 0.7666666666666667
# Particion  8
# Tasa de acierto: 0.8666666666666667
# Particion  9
# Tasa de acierto: 0.7666666666666667
# Particion  10
# Tasa de acierto: 0.8
# TODAS LAS PARTICIONES
# Tasa de acierto promedio:  0.7933
# NEIGHBORS 23
# Particion  1
# Tasa de acierto: 0.7666666666666667
# Particion  2
# Tasa de acierto: 0.6333333333333333
# Particion  3
# Tasa de acierto: 0.8
# Particion  4
# Tasa de acierto: 0.8333333333333334
# Particion  5
# Tasa de acierto: 0.8
# Particion  6
# Tasa de acierto: 0.8333333333333334
# Particion  7
# Tasa de acierto: 0.8
# Particion  8
# Tasa de acierto: 0.8666666666666667
# Particion  9
# Tasa de acierto: 0.7666666666666667
# Particion  10
# Tasa de acierto: 0.8
# TODAS LAS PARTICIONES
# Tasa de acierto promedio:  0.7900
# NEIGHBORS 24
# Particion  1
# Tasa de acierto: 0.7333333333333333
# Particion  2
# Tasa de acierto: 0.6333333333333333
# Particion  3
# Tasa de acierto: 0.8
# Particion  4
# Tasa de acierto: 0.8333333333333334
# Particion  5
# Tasa de acierto: 0.8
# Particion  6
# Tasa de acierto: 0.7666666666666667
# Particion  7
# Tasa de acierto: 0.8
# Particion  8
# Tasa de acierto: 0.8333333333333334
# Particion  9
# Tasa de acierto: 0.7666666666666667
# Particion  10
# Tasa de acierto: 0.8
# TODAS LAS PARTICIONES
# Tasa de acierto promedio:  0.7767
# NEIGHBORS 25
# Particion  1
# Tasa de acierto: 0.7333333333333333
# Particion  2
# Tasa de acierto: 0.6333333333333333
# Particion  3
# Tasa de acierto: 0.8
# Particion  4
# Tasa de acierto: 0.8333333333333334
# Particion  5
# Tasa de acierto: 0.8
# Particion  6
# Tasa de acierto: 0.8
# Particion  7
# Tasa de acierto: 0.8
# Particion  8
# Tasa de acierto: 0.8333333333333334
# Particion  9
# Tasa de acierto: 0.7666666666666667
# Particion  10
# Tasa de acierto: 0.7666666666666667
# TODAS LAS PARTICIONES
# Tasa de acierto promedio:  0.7767
# NEIGHBORS 26
# Particion  1
# Tasa de acierto: 0.7333333333333333
# Particion  2
# Tasa de acierto: 0.6333333333333333
# Particion  3
# Tasa de acierto: 0.7666666666666667
# Particion  4
# Tasa de acierto: 0.8333333333333334
# Particion  5
# Tasa de acierto: 0.8
# Particion  6
# Tasa de acierto: 0.8333333333333334
# Particion  7
# Tasa de acierto: 0.7666666666666667
# Particion  8
# Tasa de acierto: 0.8
# Particion  9
# Tasa de acierto: 0.7333333333333333
# Particion  10
# Tasa de acierto: 0.7333333333333333
# TODAS LAS PARTICIONES
# Tasa de acierto promedio:  0.7633

# %%
from pandas.core.api import DateOffset
fig, ax = plt.subplots()
datos = {'Media':medias_neig}

ax.plot(k_range, datos['Media'], "--", color = 'tab:green',marker='o', ms=5, mfc='red')
#plt.plot(x, y, "--o")
plt.ylabel('Tasa de acierto')
plt.xlabel('Vecinos')
plt.show()

# %% [markdown]
# # -------------------------------------------------------------------------------
# # CREAMOS EL MODELO CON KNN

# %%
#Se crea el modelo a partir de KNN con n=1

# %%
modelo = KNeighborsClassifier(n_neighbors=1)

# %%
#Para entrenar el modelo utilizaremos tanto los datos de entrenamiento como de test unidos, todo el conjunto de datos

datos = np.load('conjunto_datos.npy')

# %%
x_train = list()

#Cogemos la primera partición tanto de test como entrenamiento
x_train = datos

y_train = np.array([0]*int(x_train.shape[0]/3) #carton 0
                +  [1]*int(x_train.shape[0]/3)  #plastico 1
                +  [2]*int(x_train.shape[0]/3)) #cristal 2


modelo.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
import joblib

# %%
joblib.dump(modelo, 'modeloKNN.pkl')
# Out:
# ['modeloKNN.pkl']
